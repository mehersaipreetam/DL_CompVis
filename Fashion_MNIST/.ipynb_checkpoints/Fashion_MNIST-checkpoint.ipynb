# %%
from keras import datasets
(x_train, y_train), (x_test, y_test) = datasets.fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 11us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 26s 1us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 4s 1us/step

# %%
import numpy as np
import matplotlib.pyplot as plt

dict_items = {0:'T-shirt/top', 1:'Trouser', 2:'Pullover', 3:'Dress', 4:	'Coat',
              5:'Sandal', 6:'Shirt', 7:'Sneaker', 8:'Bag', 9:'Ankle boot'}

run = np.random.randint(1, 1000, 10)
fig = plt.figure()
i = 1
for r in run:
  plt.subplot(2, 5, i)
  i += 1
  plt.imshow(x_train[r],cmap = 'gray')
  plt.xlabel(dict_items[y_train[r]])

# %%
# Preprocess data

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train /= 255
x_test /= 255

from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,Maxpooling

model = Sequential()

model.add()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-8df431a72732> in <module>
#      14     weights='imagenet',  # Load weights pre-trained on ImageNet.
#      15     input_shape=input_shape,
# ---> 16     include_top=False)  # Do not include the ImageNet classifier at the top.
#
# ~/anaconda3/lib/python3.7/site-packages/keras/applications/__init__.py in wrapper(*args, **kwargs)
#      18         kwargs['models'] = models
#      19         kwargs['utils'] = utils
# ---> 20         return base_fun(*args, **kwargs)
#      21
#      22     return wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/keras/applications/vgg19.py in VGG19(*args, **kwargs)
#       9 @keras_modules_injection
#      10 def VGG19(*args, **kwargs):
# ---> 11     return vgg19.VGG19(*args, **kwargs)
#      12
#      13
#
# ~/anaconda3/lib/python3.7/site-packages/keras_applications/vgg19.py in VGG19(include_top, weights, input_tensor, input_shape, pooling, classes, **kwargs)
#      97                                       data_format=backend.image_data_format(),
#      98                                       require_flatten=include_top,
# ---> 99                                       weights=weights)
#     100
#     101     if input_tensor is None:
#
# ~/anaconda3/lib/python3.7/site-packages/keras_applications/imagenet_utils.py in _obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
#     311                 if len(input_shape) != 3:
#     312                     raise ValueError(
# --> 313                         '`input_shape` must be a tuple of three integers.')
#     314                 if input_shape[-1] != 3 and weights == 'imagenet':
#     315                     raise ValueError('The input must have 3 channels; got '
#
# ValueError: `input_shape` must be a tuple of three integers.

# %%
x_train = preprocess_input(x_train)
x_test = preprocess_input(x_test)
print(x_train.shape)
# Out:
# (60000, 28, 28)
